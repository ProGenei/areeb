# %%
# !pip install langchain_cohere
# !pip install langchain_text_splitters
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_core
# !pip install langchain_chroma
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.2 MB/s eta 0:00:00
# ...

# %%
from langchain_cohere import ChatCohere
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain_chroma import Chroma
from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)
from langchain_core.prompts import PromptTemplate
from langchain_community.document_loaders import PyPDFLoader
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 5.3 MB/s eta 0:00:00
# ...

# %%
loader = PyPDFLoader("/content/Description of all projects-1.pdf")
pages = loader.load()

# %%
import re
from langchain.text_splitter import TextSplitter
from langchain.schema import Document
from langchain.document_loaders import PyPDFLoader
import logging

# Optional: Configure logging for better visibility
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 43.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 67.9 MB/s eta 0:00:00
# ...

# %%
pages[0]
# Out:
# Document(metadata={'source': '/content/Description of all projects-1.pdf', 'page': 0}, page_content='The High Line (Phase 3)  \nDescription: The third \nphase of the High Line park, transforming a former elevated railway into a \nlinear public park with gardens, seating areas, and public art installations, \nstretching further into Manhattan’s West Side.  \n• Type : Public Park  \n• Capacity : Thousands of visitors daily  \n• Target Audience : Tourists, locals, families, art enthusiasts  \n• Impact : Revitalized the West Side of Manhattan, providing green space, \nenhancing the urban environment, and promoting sustainable urban development. \nIt has also increased property values and attracted new development in the \nsurrounding area.  \n• Popularity : Highly popular among tourists and locals for its unique combination \nof art, nature, and urban views.  \n• Congestion : Moderate to heavy, especially during weekends and tourist seasons.  \n• Borough : Manhattan  \n• Open : 2014 (Pha
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

# %%
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=5000,
    chunk_overlap=150,
    length_function=len
)

# %%
docs = text_splitter.split_documents(pages)

# %%
docs[3]
# Out:
# Document(metadata={'source': '/content/Description of all projects-1.pdf', 'page': 3}, page_content='Spring Street Salt Shed .    \n \n• Description : The Spring Street Salt Shed is an architecturally distinctive facility \nused for storing salt for New York City’s winter road maintenance. Its unique \nconcrete structure, resembling a salt crystal, has made it a notable example of \nfunctional infrastructure  designed with an artistic touch.  \n• Type : Public Infrastructure  \n• Capacity : Storage for thousands of tons of salt for winter road maintenance  \n• Target Audience : City government, maintenance staff, architecture enthusiasts  \n• Impact : The Salt Shed improves road safety by ensuring an adequate supply of \nsalt for deicing during winter. It has also become a landmark due to its modern \ndesign, integrating infrastructure with urban aesthetics and enhancing the \nstreetscape.  \n• Popularity : Not a typical tourist destination, but it has gained recognition among \narch
# ...

# %%
# !pip install -U sentence-transformers
# !pip install chromadb
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# <ipython-input-16-5789c3f8346b>:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
# !pip install persist
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 6.8 MB/s eta 0:00:00
# ...

# %%
vectordb = Chroma.from_documents(
    documents=docs,
    embedding=embedding_function,
    persist_directory='./chroma_db'
)

# %%
retriever = vectordb.as_retriever(search_kwargs={"k": 1})

# %%
template = """
the pdf is about the projects in new york city with it's details. answer the question clearly, in details, refer to the pdf content, make sure to answer right, if the question out of the topics of the pdf content, say: 'don't know the answer'
"""
prompt = PromptTemplate(template=template)

# %%
# !pip install cohere
# !pip install cohere.Client
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement cohere.Client (from versions: none)
# ERROR: No matching distribution found for cohere.Client

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "XhVgCWGf3YG16xTbnIkntiw4CaYyFsw6JUbWwDjG"

llm_model = ChatCohere(cohere_api_key="XhVgCWGf3YG16xTbnIkntiw4CaYyFsw6JUbWwDjG", model = 'command-r-plus')

# %%
from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm = llm_model,
    retriever=retriever
)

# %%
question = "what is the project that open in 2015?"
result = qa_chain({"query": question})
result["result"]
# Out:
# <ipython-input-24-d40ac6438795>:2: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain({"query": question})
# "I don't have any information about a project that opened in 2015. The only project mentioned in the text is the Summit at One Vanderbilt, which opened in 2021."

# %%
question = "?"
result = qa_chain({"query": question})
result["result"]
# Out:
# "I don't know what you mean. Could you please clarify your question?"

# %%
question = "Whitney Museum of American Art when open"
result = qa_chain({"query": question})
result["result"]
# Out:
# 'The Whitney Museum of American Art opened in its new building in the Meatpacking District, Manhattan, in 2015.'

# %%
question = "what is the biggest advantage of Whitney Museum of American Art?"
result = qa_chain({"query": question})
result["result"]
# Out:
# 'The biggest advantage of the Whitney Museum of American Art is its dedication to showcasing innovative and contemporary works by living artists. This focus on contemporary American art, especially from the 20th and 21st centuries, sets it apart as one of the foremost institutions in its field. The museum has had a significant impact on promoting and preserving modern artistic expressions, and its exhibitions are highly popular among art lovers, students, and tourists.'

# %%
question = "what is the benefit 432 Park Avenue?"
result = qa_chain({"query": question})
result["result"]
# Out:
# "432 Park Avenue offers a range of benefits that cater to the needs and desires of ultra-high-net-worth individuals and luxury home buyers:\n\n1. Exclusive Luxury Living: 432 Park Avenue provides an exclusive and luxurious lifestyle. The building features hundreds of carefully designed luxury condominiums with a minimalist aesthetic. Each residence is expected to offer spacious layouts, high-end finishes, and top-of-the-line amenities, ensuring a sophisticated and comfortable living experience.\n\n2. Breathtaking Views: One of the tower's most notable features is the panoramic views it offers. Residents can enjoy stunning vistas of iconic Central Park, the Manhattan skyline, and the surrounding cityscape. The building's height and strategic location in Midtown Manhattan allow for unparalleled visual experiences that are sure to impress.\n\n3. Central Location: The skyscraper is situated in a prime location in the heart of Midtown Manhattan. This central location provides easy access 
# ...
