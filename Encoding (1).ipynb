# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import timeseries_dataset_from_array

# %%
traffic = pd.read_csv('/content/drive/MyDrive/October 4/concate df/4oct_final_data_before_encodeing.csv')
traffic
# Out:
#          Datetime  Avg_Vol_Geo           Boro                 street  \
# 0      2012-01-01    41.246324          Bronx           RIVER AVENUE
# 1      2012-01-01    39.777778          Bronx          GERARD AVENUE
# 2      2012-01-01    95.380769          Bronx        EAST 138 STREET
# 3      2012-01-01    51.384030          Bronx        EAST 144 STREET
# 4      2012-01-01   127.368421          Bronx        EAST 149 STREET
# ...           ...          ...            ...                    ...
# 30618  2019-12-01    18.015504  Staten Island           FRONT STREET
# 30619  2019-12-01    50.969072  Staten Island           CANAL STREET
# 30620  2019-12-01    28.273902  Staten Island  MURRAY HULBERT AVENUE
# 30621  2019-12-01    29.984496  Staten Island           FRONT STREET
# 30622  2019-12-01    27.737113  Staten Island  MURRAY HULBERT AVENUE
#
#        holidays  Floor  Area (sq ft) Type_of_Project  project_active
# 0         False      0             0      No_Project           False
# 1         False      0             0      No_Project           False
# 2         False      0             0      No_Project           False
# 3         False      0             0      No_Project           False
# 4         False      0             0      No_Project           False
# ...         ...    ...           ...             ...             ...
# 30618     False      0             0      No_Project           False
# 30619     False      0             0      No_Project           False
# 30620     False      0             0      No_Project           False
# 30621     False      0             0      No_Project           False
# 30622     False      0             0      No_Project           False
#
# [30623 rows x 9 columns]

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30623 entries, 0 to 30622
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Datetime         30623 non-null  object
#  1   Avg_Vol_Geo      30623 non-null  float64
#  2   Boro             30623 non-null  object
#  3   street           30623 non-null  object
#  4   holidays         30623 non-null  bool
#  5   Floor            30623 non-null  int64
#  6   Area (sq ft)     30623 non-null  int64
#  7   Type_of_Project  30623 non-null  object
#  8   project_active   30623 non-null  bool
# dtypes: bool(2), float64(1), int64(2), object(4)
# memory usage: 1.7+ MB

# %%
traffic['Datetime'] = pd.to_datetime(traffic['Datetime'])
traffic = traffic.set_index('Datetime')
traffic = traffic.sort_index()

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30623 entries, 2012-01-01 to 2019-12-01
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Avg_Vol_Geo      30623 non-null  float64
#  1   Boro             30623 non-null  object
#  2   street           30623 non-null  object
#  3   holidays         30623 non-null  bool
#  4   Floor            30623 non-null  int64
#  5   Area (sq ft)     30623 non-null  int64
#  6   Type_of_Project  30623 non-null  object
#  7   project_active   30623 non-null  bool
# dtypes: bool(2), float64(1), int64(2), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# # Encoding

# %%
label_encoder = LabelEncoder()
traffic['street'] = label_encoder.fit_transform(traffic['street'])

# %%
traffic = pd.get_dummies(traffic, columns=['Type_of_Project', 'Boro'])

# %%
traffic.head()
# Out:
#             Avg_Vol_Geo  street  holidays  Floor  Area (sq ft)  \
# Datetime
# 2012-01-01    41.246324    2790     False      0             0
# 2012-01-01    21.768407     152     False      0             0
# 2012-01-01    65.111842    2409     False      0             0
# 2012-01-01    65.111842    2407     False      0             0
# 2012-01-01    66.202929    2807     False      0             0
#
#             project_active  Type_of_Project_Commercial Development  \
# Datetime
# 2012-01-01           False                                   False
# 2012-01-01           False                                   False
# 2012-01-01           False                                   False
# 2012-01-01           False                                   False
# 2012-01-01           False                                   False
#
#             Type_of_Project_Cultural  Type_of_Project_Educational  \
# Datetime
# 2012-01-01                     False                        False
# 2012-01-01                     False                        False
# 2012-01-01                     False                        False
# 2012-01-01                     False                        False
# 2012-01-01                     False                        False
#
#             Type_of_Project_Elevated Public Park  ...  \
# Datetime                                          ...
# 2012-01-01                                 False  ...
# 2012-01-01                                 False  ...
# 2012-01-01                                 False  ...
# 2012-01-01                                 False  ...
# 2012-01-01                                 False  ...
#
#             Type_of_Project_Outdoor Observation Deck  Type_of_Project_Park  \
# Datetime
# 2012-01-01                                     False                 False
# 2012-01-01                                     False                 False
# 2012-01-01                                     False                 False
# 2012-01-01                                     False                 False
# 2012-01-01                                     False                 False
#
#             Type_of_Project_Residential  \
# Datetime
# 2012-01-01                        False
# 2012-01-01                        False
# 2012-01-01                        False
# 2012-01-01                        False
# 2012-01-01                        False
#
#             Type_of_Project_Train Station / Transit Hub  \
# Datetime
# 2012-01-01                                        False
# 2012-01-01                                        False
# 2012-01-01                                        False
# 2012-01-01                                        False
# 2012-01-01                                        False
#
#             Type_of_Project_Transportation  Boro_Bronx  Boro_Brooklyn  \
# Datetime
# 2012-01-01                           False        True          False
# 2012-01-01                           False       False          False
# 2012-01-01                           False       False          False
# 2012-01-01                           False       False          False
# 2012-01-01                           False       False          False
#
#             Boro_Manhattan  Boro_Queens  Boro_Staten Island
# Datetime
# 2012-01-01           False        False               False
# 2012-01-01           False         True               False
# 2012-01-01           False         True               False
# 2012-01-01           False         True               False
# 2012-01-01           False         True               False
#
# [5 rows x 29 columns]

# %% [markdown]
# outliers

# %%
# prompt: is Avg_Vol_Geo outliers then visualize using boxplot

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the IQR (Interquartile Range)
Q1 = traffic['Avg_Vol_Geo'].quantile(0.25)
Q3 = traffic['Avg_Vol_Geo'].quantile(0.75)
IQR = Q3 - Q1

# Define the outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = traffic[(traffic['Avg_Vol_Geo'] < lower_bound) | (traffic['Avg_Vol_Geo'] > upper_bound)]

# Print the number of outliers
print(f"Number of outliers in Avg_Vol_Geo: {len(outliers)}")

# Visualize using boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x=traffic['Avg_Vol_Geo'])
plt.title('Boxplot of Avg_Vol_Geo')
plt.show()
# Out:
# Number of outliers in Avg_Vol_Geo: 2343
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
traffic[traffic['Avg_Vol_Geo'] > 1500]
# Out:
#             Avg_Vol_Geo  street  holidays  Floor  Area (sq ft)  \
# Datetime
# 2014-07-01  1835.611111    2326      True      0             0
#
#             project_active  Type_of_Project_Commercial Development  \
# Datetime
# 2014-07-01           False                                   False
#
#             Type_of_Project_Cultural  Type_of_Project_Educational  \
# Datetime
# 2014-07-01                     False                        False
#
#             Type_of_Project_Elevated Public Park  ...  \
# Datetime                                          ...
# 2014-07-01                                 False  ...
#
#             Type_of_Project_Outdoor Observation Deck  Type_of_Project_Park  \
# Datetime
# 2014-07-01                                     False                 False
#
#             Type_of_Project_Residential  \
# Datetime
# 2014-07-01                        False
#
#             Type_of_Project_Train Station / Transit Hub  \
# Datetime
# 2014-07-01                                        False
#
#             Type_of_Project_Transportation  Boro_Bronx  Boro_Brooklyn  \
# Datetime
# 2014-07-01                           False       False          False
#
#             Boro_Manhattan  Boro_Queens  Boro_Staten Island
# Datetime
# 2014-07-01           False         True               False
#
# [1 rows x 29 columns]

# %%
traffic = traffic.drop(traffic[traffic['Avg_Vol_Geo'] > 1500].index)

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30326 entries, 2012-01-01 to 2019-12-01
# Data columns (total 29 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Avg_Vol_Geo                                   30326 non-null  float64
#  1   street                                        30326 non-null  int64
#  2   holidays                                      30326 non-null  bool
#  3   Floor                                         30326 non-null  int64
#  4   Area (sq ft)                                  30326 non-null  int64
#  5   project_active                                30326 non-null  bool
#  6   Type_of_Project_Commercial Development        30326 non-null  bool
#  7   Type_of_Project_Cultural                      30326 non-null  bool
#  8   Type_of_Project_Educational                   30326 non-null  bool
#  9   Type_of_Project_Elevated Public Park          30326 non-null  bool
#  10  Type_of_Project_Industrial Development        30326 non-null  bool
#  11  Type_of_Project_Infrastructure                30326 non-null  bool
#  12  Type_of_Project_Interactive Museum            30326 non-null  bool
#  13  Type_of_Project_Interactive Observation Deck  30326 non-null  bool
#  14  Type_of_Project_Interactive Public Structure  30326 non-null  bool
#  15  Type_of_Project_Mixed-Use Development         30326 non-null  bool
#  16  Type_of_Project_Museum                        30326 non-null  bool
#  17  Type_of_Project_No_Project                    30326 non-null  bool
#  18  Type_of_Project_Office Building               30326 non-null  bool
#  19  Type_of_Project_Outdoor Observation Deck      30326 non-null  bool
#  20  Type_of_Project_Park                          30326 non-null  bool
#  21  Type_of_Project_Residential                   30326 non-null  bool
#  22  Type_of_Project_Train Station / Transit Hub   30326 non-null  bool
#  23  Type_of_Project_Transportation                30326 non-null  bool
#  24  Boro_Bronx                                    30326 non-null  bool
#  25  Boro_Brooklyn                                 30326 non-null  bool
#  26  Boro_Manhattan                                30326 non-null  bool
#  27  Boro_Queens                                   30326 non-null  bool
#  28  Boro_Staten Island                            30326 non-null  bool
# dtypes: bool(25), float64(1), int64(3)
# memory usage: 1.9 MB

# %% [markdown]
# ## Split the data

# %%
train_val, test = train_test_split(traffic, test_size=0.15, shuffle=False)
train, val = train_test_split(train_val, test_size=0.2, shuffle=False)

# %%
train.shape, val.shape, test.shape
# Out:
# ((20621, 29), (5156, 29), (4549, 29))

# %% [markdown]
# ## normalizing

# %%
scaler = MinMaxScaler()
numerical_cols = ['Avg_Vol_Geo', 'Area (sq ft)']

train[numerical_cols] = scaler.fit_transform(train[numerical_cols])
val[numerical_cols] = scaler.transform(val[numerical_cols])
test[numerical_cols] = scaler.transform(test[numerical_cols])

# %%
window_size = 36
time_steps = 12

def create_timeseries_dataset(df, window_size, batch_size=1024):
    # Handle missing values
    df = df.fillna(0)
    df = df.replace([np.inf, -np.inf], 0)

    # Convert to float32 NumPy array
    array = df.values.astype(np.float32)

    # Optionally, verify the array
    print(f"Array shape: {array.shape}, dtype: {array.dtype}")
    print("First 5 rows of the array:")
    print(array[:5])

    dataset = timeseries_dataset_from_array(
        data=array[:-window_size],
        targets=array[window_size:, 0],
        sequence_length=window_size,
        batch_size=batch_size
    )

    return dataset

#Assuming 'train', 'val', 'test' are your DataFrames
train_Xy = create_timeseries_dataset(train, window_size)
val_Xy = create_timeseries_dataset(val, window_size)
test_Xy = create_timeseries_dataset(test, window_size)
# Out:
# Array shape: (20621, 29), dtype: float32
# First 5 rows of the array:
# [[3.5999760e-02 2.7900000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [1.8999448e-02 1.5200000e+02 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [5.6829564e-02 2.4090000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [5.6829564e-02 2.4070000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [5.7781864e-02 2.8070000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]]
# Array shape: (5156, 29), dtype: float32
# First 5 rows of the array:
# [[7.4110003e-03 6.2500000e+02 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [2.2948645e-02 4.8900000e+02 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [9.7527523e-03 2.6500000e+02 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [2.3123983e-02 4.8900000e+02 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [3.6496515e-04 2.3250000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]]
# Array shape: (4549, 29), dtype: float32
# First 5 rows of the array:
# [[5.2490968e-02 2.5160000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.0476002e-02 2.4280000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [9.5226027e-02 3.1830000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.2548307e-01 3.4520000e+03 0.0000000e+00 1.0000000e+00 4.1440995e-03
#   1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00
#   0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [1.3682946e-02 1.1900000e+03 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]]

# %% [markdown]
# # Train the model

# %%
num_features = train.shape[1]  # Number of columns/features in the training data
print(f"Number of features: {num_features}")
# Out:
# Number of features: 29

# %%
model = Sequential([
    SimpleRNN(units=64, activation='tanh', return_sequences=False,
              input_shape=(window_size, num_features), kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(units=32, activation='relu'),
    Dropout(0.3),
    Dense(units=1, activation='relu')
])

# learning rate:
optimizer = Adam(learning_rate=0.0005)


model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])


early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)


history = model.fit(train_Xy, validation_data=(val_Xy), epochs=60, batch_size=128,
                    callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/60
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 309ms/step - loss: 0.1615 - mae: 0.1790 - val_loss: 0.0538 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 2/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - loss: 0.0583 - mae: 0.1000 - val_loss: 0.0499 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 3/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - loss: 0.0523 - mae: 0.0971 - val_loss: 0.0464 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 4/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 377ms/step - loss: 0.0478 - mae: 0.0961 - val_loss: 0.0432 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 5/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - loss: 0.0445 - mae: 0.0961 - val_loss: 0.0404 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 6/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 433ms/step - loss: 0.0418 - mae: 0.0958 - val_loss: 0.0378 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 7/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.0392 - mae: 0.0956 - val_loss: 0.0356 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 8/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.0369 - mae: 0.0957 - val_loss: 0.0335 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 9/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0350 - mae: 0.0958 - val_loss: 0.0317 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 10/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - loss: 0.0330 - mae: 0.0954 - val_loss: 0.0302 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 11/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0315 - mae: 0.0954 - val_loss: 0.0287 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 12/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 304ms/step - loss: 0.0300 - mae: 0.0953 - val_loss: 0.0275 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 13/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0289 - mae: 0.0955 - val_loss: 0.0264 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 14/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.0278 - mae: 0.0953 - val_loss: 0.0254 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 15/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 400ms/step - loss: 0.0267 - mae: 0.0952 - val_loss: 0.0246 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 16/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 0.0259 - mae: 0.0952 - val_loss: 0.0238 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 17/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0252 - mae: 0.0952 - val_loss: 0.0232 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 18/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 305ms/step - loss: 0.0246 - mae: 0.0953 - val_loss: 0.0226 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 19/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0239 - mae: 0.0952 - val_loss: 0.0221 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 20/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0235 - mae: 0.0953 - val_loss: 0.0216 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 21/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 296ms/step - loss: 0.0230 - mae: 0.0951 - val_loss: 0.0213 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 22/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - loss: 0.0226 - mae: 0.0951 - val_loss: 0.0209 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 23/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - loss: 0.0224 - mae: 0.0952 - val_loss: 0.0206 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 24/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 345ms/step - loss: 0.0221 - mae: 0.0952 - val_loss: 0.0204 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 25/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - loss: 0.0219 - mae: 0.0953 - val_loss: 0.0202 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 26/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - loss: 0.0217 - mae: 0.0953 - val_loss: 0.0200 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 27/60
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - loss: 0.0214 - mae: 0.0951 - val_loss: 0.0198 - val_mae: 0.0957 - learning_rate: 5.0000e-04
# Epoch 28/60
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - loss: 0.0100 - mae: 0.0719
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-bea30107b59c> in <cell line: 21>()
#      19
#      20
# ---> 21 history = model.fit(train_Xy, validation_data=(val_Xy), epochs=60, batch_size=128,
#      22                     callbacks=[early_stopping, reduce_lr])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316                 for step, iterator in epoch_iterator.enumerate_epoch():
#     317                     callbacks.on_train_batch_begin(step)
# --> 318                     logs = self.train_function(iterator)
#     319                     logs = self._pythonify_logs(logs)
#     320                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.show()

plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.title('Mean Absolute Error Over Epochs')
plt.legend()
plt.show()

# %%
pd.DataFrame(history.history).plot()
